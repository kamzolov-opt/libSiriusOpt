# %%
import numpy as np
import gd as g
import matplotlib.pyplot as plt

# %%
func = lambda x: 0.5*np.linalg.norm(A @ x - b)**2
grad = lambda x: A.T @ (A @ x - b)

# %%
n = 10
A = np.eye(n)*np.arange(1,11)
b = np.ones(n)
x0 = np.zeros(n)

# %%
def ternary_search_v(xk, zk, func):
    a = 0.
    b = 1. 
    while b - a > 1e-3:
        c = a + (b - a) / 3
        d = a + (b - a) / 3 * 2
        if func(xk*c+zk*(1-c)) >= func(xk*d+zk*(1-d)):
            a = c
        else:
            b = d 
    print((b + a)/2)
    return (b+a)/2

# %%
def ternary_search(a, b, xk, func, gr):
    #gr - value of gradient
    
    while b - a > 1e-3:
        c = a + (b - a) / 3
        d = a + (b - a) / 3 * 2
        if func(xk - c * gr) >= func(xk - d * gr):
            a = c
        else:
            b = d 
    print((b + a) / 2)
    return (b + a) / 2

# %%
def bin_pow_ray(a, b, xk, func, gr):
    c = (a + b) / 2
    if func(xk - c * gr) <= func(xk - b * gr):
        return ternary_search(a, b, xk, func, gr)
    else:
        return bin_pow_ray(b, 2 * b, xk, gr)

# %%
def a_next(xk, func, gr):
    return bin_pow_ray(0., 1., xk, func, gr)

# %%
 def y_next(xk, zk):
    return ternary_search_v(xk, zk, func)

# %%
def x_next(xk, grad, ak_next, yk_next):
    return xk - ak_next * grad(yk_next)

# %%
def fast_grad_step_v3(ak_next, xk_next, a_bigk, zk):
    return (ak_next * xk_next + a_bigk * zk) / (a_bigk + ak_next)

# %%
xk = x0
zk = x0
yk = x0
L = np.amax(np.linalg.eigh(A.T @ A)[0])
ak = 1 / L
a_bigk = ak
res = [func(xk)]
while True:
#for i in range(10):
    ak = a_next(xk, func, grad(yk)) 
    alpha = ternary_search_v(xk, zk, func)
    yk = xk * alpha + zk * (1 - alpha)
    xk = x_next(xk, grad, ak, yk)
    zk = xk * alpha + zk * (1 - alpha)
    a_bigk += ak
    res.append(func(zk))
    
#print(zk)
    if abs(res[-1] - res[-2]) < 1e-9:
        break
# Out:
# 0.015082981323685234
# 0.9996616802577005
# 0.0003383197422994323
# 0.9996616802577005
# 0.01815164711126055
# 0.9996616802577005
# 0.0008457993557485806
# 0.9996616802577005
# 0.016912022430491537
# 0.9996616802577005
# 0.0019876284860091643
# 0.9996616802577005
# 0.020179583222817106
# 0.9996616802577005
# 0.007004275914792933
# 0.9996616802577005
# 0.015421301065984666
# 0.9996616802577005
# 0.06001954119674863
# 0.9996616802577005
# 0.05480102524985456
# 0.9996616802577005
# 0.0003383197422994323
# 0.0003383197422994323
# 0.009956644290952821
# 0.9996616802577005
# 0.0003383197422994323
# 0.9996616802577005
# 0.33510071275554043
# 0.9996616802577005
# 0.0019876284860091643
# 0.9996616802577005
# 0.012192726337713133
# 0.9996616802577005
# 0.0035312123102503243
# 0.9996616802577005
# 0.08969099205282349
# 0.9996616802577005
# 0.0396888043781288
# 0.9996616802577005
# 0.0003383197422994323
# 0.0003383197422994323
# 0.009956644290952821
# 0.9996616802577005
# 0.0003383197422994323
# 0.9996616802577005
# 0.4611318272328131
# 0.9996616802577005
# 0.006433361349662641
# 0.9996616802577005
# 0.01116190837289455
# 0.9996616802577005
# 0.012531046080012565
# 0.9996616802577005
# 0.024506375552068443
# 0.9996616802577005
# 0.031701947493024824
# 0.9996616802577005
# 0.33311218085835403
# 0.9996616802577005
# 0.11218863543378574
# 0.9996616802577005
# 0.0003383197422994323
# 0.0003383197422994323
# 0.009787484419803106
# 0.9996616802577005
# 0.0003383197422994323
# 0.9996616802577005
# 0.023935460986938148
# 0.9996616802577005
# 0.0011841190980480128
# 0.9996616802577005
# 0.016224810453945818
# 0.9996616802577005
# 0.003150602600163463
# 0.9996616802577005
# 0.030417389721481662
# 0.9996616802577005
# 0.028089128760559696
# 0.9996616802577005
# 0.0003383197422994323
# 0.0003383197422994323
# 0.013058349115862069
# 0.9996616802577005
# 0.0006766394845988645
# 0.9996616802577005
# 0.04548864218691334
# 0.9996616802577005
# 0.005719718143249776
# 0.9996616802577005
# 0.0073848856248797945
# 0.9996616802577005
# 0.019008018958955986
# 0.9996616802577005
# 0.18496403271020595
# 0.9996616802577005
# 0.04703486913414122
# 0.9996616802577005
# 0.0003383197422994323
# 0.0003383197422994323
# 0.009787484419803106
# 0.9996616802577005
# 0.0003383197422994323
# 0.9996616802577005
# 0.09650298077033298
# 0.9996616802577005
# 0.005841301800638635
# 0.9996616802577005
# 0.0051276585942257695
# 0.9996616802577005
# 0.011246488308469407
# 0.9996616802577005
# 0.024506375552068443
# 0.9996616802577005
# 0.6070274693190014
# 0.9996616802577005
# 0.0003383197422994323
# 0.0003383197422994323
# 0.009787484419803106
# 0.9996616802577005
# 0.0003383197422994323
# 0.9996616802577005
# 0.07635891451264983
# 0.9996616802577005
# 0.0045567440290954775
# 0.9996616802577005
# 0.007004275914792933
# 0.9996616802577005
# 0.008029807633638086
# 0.9996616802577005
# 0.05158170145203651
# 0.9996616802577005
# 0.47225462564526366
# 0.9996616802577005
# 0.0003383197422994323
# 0.0003383197422994323
# 0.009956644290952821
# 0.9996616802577005
# 0.0003383197422994323
# 0.9996616802577005
# 0.013798423552142076
# 0.9996616802577005
# 0.0006766394845988645
# 0.9996616802577005
# 0.13184578887876014
# 0.9996616802577005
# 0.012953945757886855
# 0.9996616802577005
# 0.0003383197422994323
# 0.9996616802577005
# 0.15846779853710835
# 0.9996616802577005
# 0.008410417343724948
# 0.9996616802577005
# 0.002812282857864031
# 0.9996616802577005
# 0.023343401437914142
# 0.9996616802577005
# 0.014136743294441508
# 0.9996616802577005
# 0.01798248724011084
# 0.9996616802577005
# 0.1519435798347774
# 0.9996616802577005
# 0.09093061673359251
# 0.9996616802577005
# 0.0003383197422994323
# 0.0003383197422994323
# 0.009787484419803106
# 0.9996616802577005
# 0.0003383197422994323
# 0.9996616802577005
# 0.02648739623061082
# 0.9996616802577005
# 0.001437858904772587
# 0.9996616802577005
# 0.017263557787724544
# 0.9996616802577005
# 0.004176134319008616
# 0.9996616802577005
# 0.031723092476918534
# 0.9996616802577005
# 0.04703486913414122
# 0.9996616802577005
# 0.0003383197422994323
# 0.0003383197422994323

# %%
plt.plot(np.log(res))
plt.show()
